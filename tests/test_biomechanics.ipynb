# %%
import pandas as pd
import balancepy.biomechanics as bm
from balancepy.biomechanics import ComType

# %%
data = pd.read_csv('data/avoc_poc_s5_t3_sham_vrdata.csv')
com = bm.com(data['sho_tz'], data['sho_tx'], data['sho_ty'], data['hip_tz'], data['hip_tx'], data['hip_ty'], 80, 1.85, ComType.TAP)
com
# Out:
# 0       -0.006426
# 1       -0.006482
# 2       -0.006569
# 3       -0.006657
# 4       -0.006787
#            ...
# 11995    0.004385
# 11996    0.004414
# 11997    0.004391
# 11998    0.004368
# 11999    0.004327
# Length: 12000, dtype: float64
